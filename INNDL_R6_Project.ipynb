# %% [markdown]
# This project has 2 case studies. The first case study (described below - 30 points) covers concepts taught in Part 1 (the first 8
# hours of Neural networks basics).
#
#
# 1st case study - Project 1:
#
# The case study is from an open-source dataset from Kaggle.
#
# Link to the Kaggle project site:
#
# https://www.kaggle.com/barelydedicated/bank-customer-churn-modeling
#
#
# Given a Bank customer, can we build a classifier that can determine whether they will leave or not using Neural networks?
#
# Case file:
#
# bank.csv
#
#
#
# The points distribution for this case is as follows:
# 1. Read the dataset
# 2. Drop the columns which are unique for all users like IDs (2.5 points)
# 3. Distinguish the feature and target set (2.5 points)
# 4. Divide the data set into train and test sets
# 5. Normalize the train and test data (2.5 points)
# 6. Initialize & build the model (10 points)
# 7. Optimize the model (5 points)
# 9. Predict the results using 0.5 as a threshold (5 points)
# 10. Print the Accuracy score and confusion matrix (2.5 points)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
bankDF=pd.read_csv('/content/drive/My Drive/Churn.csv')

# %% [markdown]
# ## 1. Read the dataset

# %%
bankDF.head(5)
# Out:
#    RowNumber  CustomerId   Surname  ...  IsActiveMember EstimatedSalary Exited
# 0          1    15634602  Hargrave  ...               1       101348.88      1
# 1          2    15647311      Hill  ...               1       112542.58      0
# 2          3    15619304      Onio  ...               0       113931.57      1
# 3          4    15701354      Boni  ...               0        93826.63      0
# 4          5    15737888  Mitchell  ...               1        79084.10      0
#
# [5 rows x 14 columns]

# %%
bankDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
# RowNumber          10000 non-null int64
# CustomerId         10000 non-null int64
# Surname            10000 non-null object
# CreditScore        10000 non-null int64
# Geography          10000 non-null object
# Gender             10000 non-null object
# Age                10000 non-null int64
# Tenure             10000 non-null int64
# Balance            10000 non-null float64
# NumOfProducts      10000 non-null int64
# HasCrCard          10000 non-null int64
# IsActiveMember     10000 non-null int64
# EstimatedSalary    10000 non-null float64
# Exited             10000 non-null int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %% [markdown]
# ## 2. Drop the columns which are unique for all users like IDs

# %%
bankDF.nunique()
# Out:
# RowNumber          10000
# CustomerId         10000
# Surname             2932
# CreditScore          460
# Geography              3
# Gender                 2
# Age                   70
# Tenure                11
# Balance             6382
# NumOfProducts          4
# HasCrCard              2
# IsActiveMember         2
# EstimatedSalary     9999
# Exited                 2
# dtype: int64

# %%
# Since RowNumber and CustomerId are unique for all the users, dropping the columns
bankDF.drop(['RowNumber','CustomerId'],axis=1,inplace=True)

# %%
#Finding the number of counts in each categorical columns
for i in bankDF.columns:
    if bankDF[i].dtype == 'O':
        print(i,'->',len(bankDF[i].value_counts()))
# Out:
# Surname -> 2932
# Geography -> 3
# Gender -> 2

# %%
# Since Surname column is also unique for all users, dropping the column
bankDF.drop(columns = ['Surname'],inplace=True)

# %%
#Manual Encoding
bankDF.replace({'France':0,'Germany':1,'Spain':2,'Male':0,'Female':1},inplace=True)

# %%
bankDF.head()
# Out:
#    CreditScore  Geography  Gender  ...  IsActiveMember  EstimatedSalary  Exited
# 0          619          0       1  ...               1        101348.88       1
# 1          608          2       1  ...               1        112542.58       0
# 2          502          0       1  ...               0        113931.57       1
# 3          699          0       1  ...               0         93826.63       0
# 4          850          2       1  ...               1         79084.10       0
#
# [5 rows x 11 columns]

# %% [markdown]
# ## 3. Distinguish the feature and target set

# %%
from sklearn.model_selection import train_test_split

X = bankDF.drop("Exited", axis=1)
X = X.drop({'Geography','Gender'}, axis=1)
X = X.astype('float32')

# %%
y = bankDF[['Exited']]
y = y.astype('float32')

# %%
X = np.array(X)
y = np.array(y)

# %%
X.dtype
# Out:
# dtype('float32')

# %% [markdown]
# ## 4. Divide the data set into train and test sets

# %%
train_set, test_set, train_labels, test_labels = train_test_split(X, y, test_size=0.30, random_state=1)

# %% [markdown]
# ## 5. Normalize the train and test data

# %%
# %tensorflow_version 2.x
# Out:
# TensorFlow 2.x selected.

# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.0.0'

# %%
import keras
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## 6. Initialize & build the model

# %%
from sklearn.preprocessing import Normalizer
transformer = Normalizer()
train_set = transformer.fit_transform(train_set)

# %%
model = tf.keras.models.Sequential()

model.add(tf.keras.layers.Dense(2, activation='softmax'))

model.compile(optimizer='sgd', loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ## 7. Optimize the model

# %%
model.fit(train_set, train_labels, 
          validation_data=(test_set, test_labels), 
          epochs=100,
          batch_size=32)
# Out:
# Train on 7000 samples, validate on 3000 samples
# Epoch 1/100
# 7000/7000 [==============================] - 1s 207us/sample - loss: 0.2880 - accuracy: 0.6303 - val_loss: 11671.8149 - val_accuracy: 0.6363
# Epoch 2/100
# 7000/7000 [==============================] - 0s 67us/sample - loss: 0.2830 - accuracy: 0.5994 - val_loss: 9824.3792 - val_accuracy: 0.6367
# Epoch 3/100
# 7000/7000 [==============================] - 0s 64us/sample - loss: 0.2814 - accuracy: 0.5911 - val_loss: 8643.0391 - val_accuracy: 0.6370
# Epoch 4/100
# 7000/7000 [==============================] - 0s 64us/sample - loss: 0.2806 - accuracy: 0.5931 - val_loss: 8034.3684 - val_accuracy: 0.9973
# Epoch 5/100
# 7000/7000 [==============================] - 0s 66us/sample - loss: 0.2801 - accuracy: 0.6029 - val_loss: 7738.9583 - val_accuracy: 0.9993
# Epoch 6/100
# 7000/7000 [==============================] - 0s 62us/sample - loss: 0.2797 - accuracy: 0.6120 - val_loss: 7503.3194 - val_accuracy: 0.9993
# Epoch 7/100
# 7000/7000 [==============================] - 0s 65us/sample - loss: 0.2793 - accuracy: 0.4533 - val_loss: 4109.5542 - val_accuracy: 0.9997
# Epoch 82/100
# 7000/7000 [==============================] - 0s 67us/sample - loss: 0.2793 - accuracy: 0.4533 - val_loss: 4081.8689 - val_accuracy: 0.9997
# Epoch 83/100
# 7000/7000 [==============================] - 0s 67us/sample - loss: 0.2793 - accuracy: 0.4537 - val_loss: 4053.4369 - val_accuracy: 0.9997
# Epoch 84/100
# 7000/7000 [==============================] - 0s 65us/sample - loss: 0.2793 - accuracy: 0.4543 - val_loss: 4022.6629 - val_accuracy: 0.9997
# Epoch 85/100
# 7000/7000 [==============================] - 0s 70us/sample - loss: 0.2793 - accuracy: 0.4531 - val_loss: 3997.4523 - val_accuracy: 0.9997
# Epoch 86/100
# 7000/7000 [==============================] - 1s 72us/sample - loss: 0.2793 - accuracy: 0.4536 - val_loss: 3971.2115 - val_accuracy: 0.9997
# Epoch 87/100
# 7000/7000 [==============================] - 0s 71us/sample - loss: 0.2793 - accuracy: 0.4537 - val_loss: 3943.4358 - val_accuracy: 0.9997
# Epoch 88/100
# 7000/7000 [==============================] - 0s 67us/sample - loss: 0.2793 - accuracy: 0.4533 - val_loss: 3917.7505 - val_accuracy: 0.9997
# Epoch 89/100
# 7000/7000 [==============================] - 0s 71us/sample - loss: 0.2793 - accuracy: 0.4533 - val_loss: 3891.3554 - val_accuracy: 0.9997
# Epoch 90/100
# 7000/7000 [==============================] - 0s 68us/sample - loss: 0.2793 - accuracy: 0.4536 - val_loss: 3864.6948 - val_accuracy: 0.9997
# Epoch 91/100
# 7000/7000 [==============================] - 0s 64us/sample - loss: 0.2793 - accuracy: 0.4536 - val_loss: 3838.9829 - val_accuracy: 0.9997
# Epoch 92/100
# 7000/7000 [==============================] - 0s 67us/sample - loss: 0.2793 - accuracy: 0.4540 - val_loss: 3810.8426 - val_accuracy: 0.9997
# Epoch 93/100
# 7000/7000 [==============================] - 0s 65us/sample - loss: 0.2793 - accuracy: 0.4531 - val_loss: 3787.4399 - val_accuracy: 0.9997
# Epoch 94/100
# 7000/7000 [==============================] - 0s 67us/sample - loss: 0.2793 - accuracy: 0.4541 - val_loss: 3760.3209 - val_accuracy: 0.9997
# Epoch 95/100
# 7000/7000 [==============================] - 0s 63us/sample - loss: 0.2792 - accuracy: 0.4534 - val_loss: 3736.3941 - val_accuracy: 0.9997
# Epoch 96/100
# 7000/7000 [==============================] - 0s 64us/sample - loss: 0.2792 - accuracy: 0.4541 - val_loss: 3708.3044 - val_accuracy: 0.9997
# Epoch 97/100
# 7000/7000 [==============================] - 0s 64us/sample - loss: 0.2792 - accuracy: 0.4537 - val_loss: 3683.8057 - val_accuracy: 0.9997
# Epoch 98/100
# 7000/7000 [==============================] - 0s 65us/sample - loss: 0.2792 - accuracy: 0.4533 - val_loss: 3661.5355 - val_accuracy: 0.9997
# Epoch 99/100
# 7000/7000 [==============================] - 0s 64us/sample - loss: 0.2792 - accuracy: 0.4533 - val_loss: 3636.9385 - val_accuracy: 0.9997
# Epoch 100/100
# 7000/7000 [==============================] - 0s 63us/sample - loss: 0.2792 - accuracy: 0.4543 - val_loss: 3611.4265 - val_accuracy: 0.9997

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                multiple                  18
# =================================================================
# Total params: 18
# Trainable params: 18
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 9. Predict the results using 0.5 as a threshold

# %%
w = tf.zeros(shape=(8,1))
b = tf.zeros(shape=(1))

# %%
def prediction(x, w, b):
    
    xw_matmul = tf.matmul(x, w)
    y = tf.add(xw_matmul, b)
    
    return y

# %%
def loss(y_actual, y_predicted):
    
    diff = y_actual - y_predicted
    sqr = tf.square(diff)
    avg = tf.reduce_mean(sqr)
    
    return avg

# %%
def train(x, y_actual, w, b, learning_rate=0.5):
    
    #Record mathematical operations on 'tape' to calculate loss
    with tf.GradientTape() as t:
        
        t.watch([w,b])
        
        current_prediction = prediction(x, w, b)
        current_loss = loss(y_actual, current_prediction)
    
    #Calculate Gradients for Loss with respect to Weights and Bias
    dw, db = t.gradient(current_loss,[w, b])
    
    #Update Weights and Bias
    w = w - learning_rate*dw
    b = b - learning_rate*db
    
    return w, b

# %%
for i in range(100):
    
    w, b = train(train_set, train_labels, w, b,learning_rate=0.5)
    print('Current Loss on iteration', i, loss(train_labels, prediction(train_set, w, b)).numpy())
# Out:
# Current Loss on iteration 0 0.18394153
# Current Loss on iteration 1 0.17357147
# Current Loss on iteration 2 0.1674215
# Current Loss on iteration 3 0.1637743
# Current Loss on iteration 4 0.16161068
# Current Loss on iteration 5 0.16032697
# Current Loss on iteration 6 0.15956557
# Current Loss on iteration 7 0.15911308
# Current Loss on iteration 8 0.15884472
# Current Loss on iteration 9 0.15868485
# Current Loss on iteration 10 0.1585897
# Current Loss on iteration 11 0.15853271
# Current Loss on iteration 12 0.1584987
# Current Loss on iteration 13 0.15847796
# Current Loss on iteration 14 0.15846527
# Current Loss on iteration 15 0.15845731
# Current Loss on iteration 16 0.15845248
# Current Loss on iteration 17 0.15844901
# Current Loss on iteration 18 0.15844648
# Current Loss on iteration 19 0.15844475
# Current Loss on iteration 20 0.15844326
# Current Loss on iteration 21 0.15844205
# Current Loss on iteration 22 0.15844104
# Current Loss on iteration 23 0.15843996
# Current Loss on iteration 24 0.15843911
# Current Loss on iteration 25 0.15843815
# Current Loss on iteration 26 0.15843733
# Current Loss on iteration 27 0.15843639
# Current Loss on iteration 28 0.15843546
# Current Loss on iteration 29 0.15843464
# Current Loss on iteration 30 0.15843388
# Current Loss on iteration 31 0.15843304
# Current Loss on iteration 32 0.15843222
# Current Loss on iteration 33 0.15843149
# Current Loss on iteration 34 0.15843064
# Current Loss on iteration 35 0.15842992
# Current Loss on iteration 36 0.15842916
# Current Loss on iteration 37 0.15842836
# Current Loss on iteration 38 0.15842767
# Current Loss on iteration 39 0.15842688
# Current Loss on iteration 40 0.1584262
# Current Loss on iteration 41 0.1584255
# Current Loss on iteration 42 0.15842485
# Current Loss on iteration 43 0.15842411
# Current Loss on iteration 44 0.15842341
# Current Loss on iteration 45 0.15842275
# Current Loss on iteration 46 0.15842205
# Current Loss on iteration 47 0.15842138
# Current Loss on iteration 48 0.15842068
# Current Loss on iteration 49 0.1584201
# Current Loss on iteration 50 0.15841945
# Current Loss on iteration 51 0.15841888
# Current Loss on iteration 52 0.15841821
# Current Loss on iteration 53 0.15841766
# Current Loss on iteration 54 0.15841696
# Current Loss on iteration 55 0.15841636
# Current Loss on iteration 56 0.15841582
# Current Loss on iteration 57 0.15841518
# Current Loss on iteration 58 0.15841469
# Current Loss on iteration 59 0.15841411
# Current Loss on iteration 60 0.1584135
# Current Loss on iteration 61 0.15841298
# Current Loss on iteration 62 0.15841241
# Current Loss on iteration 63 0.1584119
# Current Loss on iteration 64 0.15841135
# Current Loss on iteration 65 0.15841085
# Current Loss on iteration 66 0.15841037
# Current Loss on iteration 67 0.1584098
# Current Loss on iteration 68 0.1584093
# Current Loss on iteration 69 0.15840879
# Current Loss on iteration 70 0.15840825
# Current Loss on iteration 71 0.15840788
# Current Loss on iteration 72 0.15840733
# Current Loss on iteration 73 0.15840691
# Current Loss on iteration 74 0.15840642
# Current Loss on iteration 75 0.15840593
# Current Loss on iteration 76 0.15840551
# Current Loss on iteration 77 0.15840504
# Current Loss on iteration 78 0.15840457
# Current Loss on iteration 79 0.15840417
# Current Loss on iteration 80 0.15840368
# Current Loss on iteration 81 0.15840325
# Current Loss on iteration 82 0.1584029
# Current Loss on iteration 83 0.15840249
# Current Loss on iteration 84 0.15840207
# Current Loss on iteration 85 0.1584017
# Current Loss on iteration 86 0.15840122
# Current Loss on iteration 87 0.1584008
# Current Loss on iteration 88 0.15840048
# Current Loss on iteration 89 0.15840003
# Current Loss on iteration 90 0.15839967
# Current Loss on iteration 91 0.15839931
# Current Loss on iteration 92 0.15839891
# Current Loss on iteration 93 0.15839858
# Current Loss on iteration 94 0.15839821
# Current Loss on iteration 95 0.15839784
# Current Loss on iteration 96 0.1583975
# Current Loss on iteration 97 0.15839712
# Current Loss on iteration 98 0.15839677
# Current Loss on iteration 99 0.15839647

# %% [markdown]
# ## 10. Print the Accuracy score and confusion matrix

# %%
from sklearn.metrics import accuracy_score
y_predict = model.predict_classes(test_set, verbose=0)

# %%
# accuracy: (tp + tn) / (p + n)
accuracy = accuracy_score(test_labels, y_predict)
print('Accuracy: %f' % accuracy)
# Out:
# Accuracy: 0.790667

# %%
# precision tp / (tp + fp)
from sklearn.metrics import precision_score
precision = precision_score(test_labels, y_predict)
print('Precision: %f' % precision)
# Out:
# Precision: 0.000000

# %%
# recall: tp / (tp + fn)
from sklearn.metrics import recall_score
recall = recall_score(test_labels, y_predict)
print('Recall: %f' % recall)
# Out:
# Recall: 0.000000

# %%
# f1: 2 tp / (2 tp + fp + fn)
from sklearn.metrics import f1_score
f1 = f1_score(test_labels, y_predict)
print('F1 score: %f' % f1)
# Out:
# F1 score: 0.000000

# %%
from sklearn.metrics import confusion_matrix
# confusion matrix
matrix = confusion_matrix(test_labels, y_predict)
print(matrix)
# Out:
# [[2372    1]
#  [ 627    0]]
